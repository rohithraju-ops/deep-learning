# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def neuron(inputs, weights, bias):
    z = np.dot(inputs, weights) + bias 
    return sigmoid(z)

inputs = np.array([3 , 7])
weights = np.array([0.5, 0.3])
bias = -1.0

output = neuron(inputs, weights, bias)
print("neuron output:", output)
# Out:
# neuron output: 0.9308615796566533

# %%
X = np.array([1,2])

#Hidden layer -- 3 neurons
W1 = np.random.randn(2,3)
b1 = np.zeros(3)

#Output layer -- 3 to one output
W2 = np.random.randn(3,1)
b2 = np.zeros(1)

#Forward pass
hidden = sigmoid(np.dot(X,W1)+b1)
output = sigmoid(np.dot(hidden,W2)+b2) 

print(f"Hidden layer activations: {hidden}")
print(f"Final output: {output[0]:.4f}")
# Out:
# Hidden layer activations: [0.77055906 0.96197722 0.77976808]
# Final output: 0.6798
